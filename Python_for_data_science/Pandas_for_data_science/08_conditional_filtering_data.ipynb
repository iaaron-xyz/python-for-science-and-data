# %% [markdown]
# # Conditional filtering

# %% [markdown]
# Windows

# %%
# Import the libraries
import os
import pandas as pd

# Read the data from a CSV file
# Get the absolute path to the current notebook
os_path = os.getcwd()
# Add the extra path to the dataset file
dataset_path = os_path+'\datasets\Online_Retail.csv'
retail_data = pd.read_csv(dataset_path, encoding='ISO-8859-1')

# Convert the column "InvoiceDate" to a datetime type
retail_data['InvoiceDate'] = pd.to_datetime(retail_data['InvoiceDate'])

# Delete the rows in important columns with empty values
retail_data.dropna(subset=['CustomerID', 'InvoiceDate'], inplace=True)

# Create a new column 'TotalPrice'
retail_data['TotalPrice'] = retail_data['Quantity'] * retail_data['UnitPrice']

retail_data
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_15592\2939207812.py:13: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   retail_data['InvoiceDate'] = pd.to_datetime(retail_data['InvoiceDate'])
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# ...

# %% [markdown]
# ## Filter for a specific element

# %% [markdown]
# Filter only the sales made to Malta

# %%
malta_sales = retail_data[retail_data['Country'] == 'Malta']
malta_sales
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 217684    555931     22784                LANTERN CREAM GAZEBO          3
# 217685    555931    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 217686    555931     21733     RED HANGING HEART T-LIGHT HOLDER         6
# 217687    555931     21126   SET OF 6 GIRLS CELEBRATION CANDLES        12
# 217688    555931    72140E              BEST DAD CANDLE LETTERS         6
# ...          ...       ...                                  ...       ...
# 516550   C579929     22768           FAMILY PHOTO FRAME CORNICE        -2
# 516551   C579929    85034C          3 ROSE MORRIS BOXED CANDLES        -1
# 516552   C579929    72807C  SET/3 VANILLA SCENTED CANDLE IN BOX        -1
# 516553   C579929     22307     GOLD MUG BONE CHINA TREE OF LIFE        -1
# 516554   C579929     72741                GRAND CHOCOLATECANDLE        -3
#
#                InvoiceDate  UnitPrice  CustomerID Country  TotalPrice
# ...

# %% [markdown]
# ## Filter by quantity

# %%
quantity_20 = retail_data[retail_data['Quantity'] == 20]
quantity_20
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 38        536370     22661  CHARLOTTE BAG DOLLY GIRL DESIGN        20
# 263       536394     22652                TRAVEL SEWING KIT        20
# 1105      536526     21929   JUMBO BAG PINK VINTAGE PAISLEY        20
# 1312      536533     22680    FRENCH BLUE METAL DOOR SIGN 5        20
# 1427      536542     22383          LUNCH BAG SUKI  DESIGN         20
# ...          ...       ...                              ...       ...
# 541232    581496     22664       TOY TIDY DOLLY GIRL DESIGN        20
# 541608    581514     22069    BROWN  PIRATE TREASURE CHEST         20
# 541727    581570     23077              DOUGHNUT LIP GLOSS         20
# 541832    581579     23201               JUMBO BAG ALPHABET        20
# 541834    581579     23344        JUMBO BAG 50'S CHRISTMAS         20
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %% [markdown]
# ## Filter using Multiple Conditions

# %% [markdown]
# You can combine multiple boolean conditions using the pandas' logic operators:
#
# - `&` para *AND*.
#
# - `|` para *OR*.
#
# - `~` para *NOT*.
#
# Remember always enclose in parenthesis `()` every boolean condition.

# %% [markdown]
# Get only the rows with France as a country and with exactly 20 sales.

# %%
retail_fra_greater_20 = retail_data[(retail_data['Quantity'] == 20) & (retail_data['Country'] == 'France')]
retail_fra_greater_20
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 38        536370     22661  CHARLOTTE BAG DOLLY GIRL DESIGN        20
# 7914      537065     20726               LUNCH BAG WOODLAND        20
# 19840     537897     22661  CHARLOTTE BAG DOLLY GIRL DESIGN        20
# 20083     538008     22437    SET OF 9 BLACK SKULL BALLOONS        20
# 23287     538196     48138               DOORMAT UNION FLAG        20
# ...          ...       ...                              ...       ...
# 518832    580120    85099B          JUMBO BAG RED RETROSPOT        20
# 519669    580160     23508   MINI PLAYING CARDS DOLLY GIRL         20
# 523369    580509     23077              DOUGHNUT LIP GLOSS         20
# 524171    580536     23199                 JUMBO BAG APPLES        20
# 529618    580736     22437    SET OF 9 BLACK SKULL BALLOONS        20
#
#                InvoiceDate  UnitPrice  CustomerID Country  TotalPrice
# ...

# %% [markdown]
# ## Filter by Year

# %% [markdown]
# Get the rows made in the year 2010

# %%
sales_2010 = retail_data[retail_data['InvoiceDate'].dt.year == 2010]
sales_2010
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 0        536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365     71053                  WHITE METAL LANTERN         6
# 2        536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...         ...       ...                                  ...       ...
# 42448    539988     84380    SET OF 3 BUTTERFLY COOKIE CUTTERS         1
# 42449    539988    84849D                HOT BATHS SOAP HOLDER         1
# 42450    539988    84849B               FAIRY SOAP SOAP HOLDER         1
# 42451    539988     22854          CREAM SWEETHEART EGG HOLDER         2
# 42452    539988    47559B                  TEA TIME OVEN GLOVE         2
#
#               InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %% [markdown]
# Get the sales made in the year 2010 only in Germany

# %%
sales_germany_2010 = retail_data[
    (retail_data["InvoiceDate"].dt.year == 2010) & (retail_data["Country"] == "Germany")
]
sales_germany_2010
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 1109     536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1110     536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 1111     536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 1112     536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 1113     536527     22244           3 HOOK HANGER MAGIC GARDEN        12
# ...         ...       ...                                  ...       ...
# 41757    539957     22533     MAGIC DRAWING SLATE BAKE A CAKE         24
# 41758    539957     22534        MAGIC DRAWING SLATE SPACEBOY         24
# 41759    539957     22634       CHILDS BREAKFAST SET SPACEBOY          2
# 41760    539957     22555            PLASTERS IN TIN STRONGMAN        12
# 41761    539957      POST                              POSTAGE         6
#
#               InvoiceDate  UnitPrice  CustomerID  Country  TotalPrice
# ...

# %% [markdown]
# ## Filter by year and month

# %% [markdown]
# Get the sales made in the UK in the year 2011 in the month of December

# %%
sales_uk_2011 = retail_data[
    (retail_data["InvoiceDate"].dt.year == 2011) & (retail_data["InvoiceDate"].dt.month == 12) & (retail_data["Country"] == "United Kingdom")
]
sales_uk_2011
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 516384   C579889     23245           SET OF 3 REGENCY CAKE TINS        -8
# 516385   C579890     84947    ANTIQUE SILVER TEA GLASS ENGRAVED        -1
# 516386   C579890     23374              RED SPOT PAPER GIFT BAG        -1
# 516387   C579890     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        -2
# 516388   C579891     23485        BOTANICAL GARDENS WALL CLOCK         -1
# ...          ...       ...                                  ...       ...
# 541889    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541891    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %% [markdown]
# ## Filter by using the `isin()` method

# %% [markdown]
# This method is iseful to find elements within a column or Series that match with specific values.

# %%
filter_isin = retail_data[retail_data['Country'].isin(['Spain', 'Monaco'])]
filter_isin
# Out:
#        InvoiceNo StockCode                    Description  Quantity  \
# 6421      536944     22383        LUNCH BAG SUKI  DESIGN         70
# 6422      536944     22384        LUNCH BAG PINK POLKADOT       100
# 6423      536944     20727        LUNCH BAG  BLACK SKULL.        60
# 6424      536944     20725        LUNCH BAG RED RETROSPOT        70
# 6425      536944     20728            LUNCH BAG CARS BLUE       100
# ...          ...       ...                            ...       ...
# 535271    581193     23291       DOLLY GIRL CHILDRENS CUP         2
# 535272    581193    85232D  SET/3 DECOUPAGE STACKING TINS         1
# 535273    581193     22721  SET OF 3 CAKE TINS SKETCHBOOK         2
# 535274    581193     23241   TREASURE TIN GYMKHANA DESIGN         1
# 535275    581193     23247     BISCUIT TIN 50'S CHRISTMAS         1
#
#                InvoiceDate  UnitPrice  CustomerID Country  TotalPrice
# 6421   2010-12-03 12:20:00       1.65     12557.0   Spain      115.50
# ...

# %% [markdown]
# ## Filter empty or null values

# %% [markdown]
# In this example, there are not empty (`None`, `null`, etc) values.

# %%
filter_nulls = retail_data[retail_data['Description'].isnull()]
filter_nulls
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, TotalPrice]
# Index: []

# %% [markdown]
# ## Filter complex conditions using the `query()` method

# %% [markdown]
# Pandas provides the `query()` method to filter using conditions wit SQL similar syntaxis.

# %%
# Filter rows where the TotalPrice is bigger that 400.00 and Quantity is less than 30
filter_query_totalprice = retail_data.query('TotalPrice > 400 and Quantity < 30')
filter_query_totalprice
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 16437     537659     21769       VINTAGE POST OFFICE CABINET        10
# 32785     539144    84078A  SET/4 WHITE RETRO STORAGE CUBES         16
# 33986     539312    84078A  SET/4 WHITE RETRO STORAGE CUBES         12
# 54305     540908    84078A  SET/4 WHITE RETRO STORAGE CUBES         16
# 61549     541426     22823     CHEST NATURAL WOOD 20 DRAWERS         4
# ...          ...       ...                               ...       ...
# 475499    576897      POST                           POSTAGE         7
# 490300    578042     22826     LOVE SEAT ANTIQUE WHITE METAL         6
# 494728    578270       DOT                    DOTCOM POSTAGE         1
# 508459    579196       DOT                    DOTCOM POSTAGE         1
# 528082    580727       DOT                    DOTCOM POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %% [markdown]
# ## Filter by text in strings using `str.contains()`

# %% [markdown]
# If you need to find a substring in a chain of text, then the method for you is `str.contains()` to search patterns in columns of type `string`.

# %% [markdown]
# In this example, search for all rows that contain the sub-string `SPACE` in the **Decription**.

# %%
filter_strcontains = retail_data[retail_data['Description'].str.contains('SPACE')]
filter_strcontains
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 35        536370     22629                 SPACEBOY LUNCH BOX         24
# 43        536370     22544                MINI JIGSAW SPACEBOY        24
# 369       536401     22382          LUNCH BAG SPACEBOY DESIGN          2
# 402       536404     21062              PARTY INVITES SPACEMAN        12
# 405       536404     22964  3 PIECE SPACEBOY COOKIE CUTTER SET        12
# ...          ...       ...                                 ...       ...
# 541772    581578     23389              SPACEBOY MINI BACKPACK         4
# 541901    581587     22367     CHILDRENS APRON SPACEBOY DESIGN         8
# 541902    581587     22629                 SPACEBOY LUNCH BOX         12
# 541903    581587     23256         CHILDRENS CUTLERY SPACEBOY          4
# 541904    581587     22613         PACK OF 20 SPACEBOY NAPKINS        12
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %% [markdown]
# ## Filter using indexes

# %% [markdown]
# To filter using the indexes of a row you can use `loc[]` and `iloc[]`. Check the next example:

# %%
# Get only the indexes 2 and 43
filter_index_0and43 = retail_data.loc[[2,43]]
filter_index_0and43
# Out:
#    InvoiceNo StockCode                     Description  Quantity  \
# 2     536365    84406B  CREAM CUPID HEARTS COAT HANGER         8
# 43    536370     22544            MINI JIGSAW SPACEBOY        24
#
#            InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 43 2010-12-01 08:45:00       0.42     12583.0          France       10.08

# %%
# Get the indexes 35 to 43
filter_index_35to43 = retail_data.iloc[35:44]
filter_index_35to43
# Out:
#    InvoiceNo StockCode                       Description  Quantity  \
# 35    536370     22629               SPACEBOY LUNCH BOX         24
# 36    536370     22659           LUNCH BOX I LOVE LONDON        24
# 37    536370     22631          CIRCUS PARADE LUNCH BOX         24
# 38    536370     22661   CHARLOTTE BAG DOLLY GIRL DESIGN        20
# 39    536370     21731     RED TOADSTOOL LED NIGHT LIGHT        24
# 40    536370     22900   SET 2 TEA TOWELS I LOVE LONDON         24
# 41    536370     21913    VINTAGE SEASIDE JIGSAW PUZZLES        12
# 42    536370     22540        MINI JIGSAW CIRCUS PARADE         24
# 43    536370     22544              MINI JIGSAW SPACEBOY        24
#
#            InvoiceDate  UnitPrice  CustomerID Country  TotalPrice
# 35 2010-12-01 08:45:00       1.95     12583.0  France       46.80
# 36 2010-12-01 08:45:00       1.95     12583.0  France       46.80
# 37 2010-12-01 08:45:00       1.95     12583.0  France       46.80
# ...

# %% [markdown]
# ## Filter only unique rows using `drop_duplicates()`

# %% [markdown]
# The `drop_duplicates()` is ised to filter the duplicated rows.

# %%
filter_duplicates = retail_data.drop_duplicates()
filter_duplicates
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %% [markdown]
# Remove duplicated rows only based on specific columns, apply it to countries to get only a different country on each row.

# %%
filter_duplicates_row = retail_data.drop_duplicates(subset='Country')
filter_duplicates_row
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 26        536370     22728            ALARM CLOCK BAKELIKE PINK        24
# 197       536389     22941         CHRISTMAS LIGHTS 10 REINDEER         6
# 385       536403     22867              HAND WARMER BIRD DESIGN        96
# 1109      536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1236      536532     84692          BOX OF 24 COCKTAIL PARASOLS        50
# 1404      536540     22968           ROSE COTTAGE KEEPSAKE BOX          4
# 5320      536858     22326  ROUND SNACK BOXES SET OF4 WOODLAND         30
# 6421      536944     22383              LUNCH BAG SUKI  DESIGN         70
# 6608      536971     21733     RED HANGING HEART T-LIGHT HOLDER        32
# 7134      536990     21992       VINTAGE PAISLEY STATIONERY SET         6
# 7214      537022     22791         T-LIGHT GLASS FLUTED ANTIQUE        12
# ...

# %% [markdown]
# ## Filter by a range of values using `between()`

# %% [markdown]
# The method `between()` allows to filter within a given range. In the next example, find only the uitary prices that are between 20 and 30.

# %%
filter_between = retail_data[retail_data['UnitPrice'].between(20,30)]
filter_between
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 141      C536379         D                         Discount        -1
# 2251      536569     21761  WOOD AND GLASS MEDICINE CABINET         1
# 5243      536851     22503        CABIN BAG VINTAGE PAISLEY         6
# 5249      536851     22504      CABIN BAG VINTAGE RETROSPOT         6
# 7006      536985     22504      CABIN BAG VINTAGE RETROSPOT         1
# ...          ...       ...                              ...       ...
# 533678    581098     22782    SET 3 WICKER STORAGE BASKETS          2
# 533682    581099     23485    BOTANICAL GARDENS WALL CLOCK          1
# 535048    581182      POST                          POSTAGE         4
# 538070    581395     23485    BOTANICAL GARDENS WALL CLOCK          1
# 539888    581449     23485    BOTANICAL GARDENS WALL CLOCK          1
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...
